# %% [markdown]
# In this project we will clean the data and analyze the included car listings. We will import the Numpy and Pandas libraries for assistance.
# We start by reading in the CSV file, and having a high level look via df.info() and df.head().

# %%
import pandas as pd

# %%
import numpy as np

# %%
autos = pd.read_csv("autos.csv", encoding = "Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [raw]
# The first few things to notice in AUTOS dataframe is that there are 15 string columns and 5 integer columns.
# The vehicle type, gearbox, model, fueltype and notRepairedDamage columns have null values.
# Also, we have to convert the column names to snakecase.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.rename({"yearOfRegistration":"registration_year"}, axis=1, inplace=True)
autos.rename({"monthOfRegistration":"registration_month"}, axis=1, inplace=True)
autos.rename({"notRepairedDamage":"unrepaired_damage"}, axis=1, inplace=True)
autos.rename({"dateCreated":"ad_created"}, axis=1, inplace=True)
autos.rename({"dateCrawled":"date_crawled"}, axis=1, inplace=True)
autos.rename({"offerType":"offer_type"}, axis=1, inplace=True)
autos.rename({"vehicleType":"vehicle_type"}, axis=1, inplace=True)
autos.rename({"powerPS":"power_ps"}, axis=1, inplace=True)
autos.rename({"fuelType":"fuel_type"}, axis=1, inplace=True)
autos.rename({"nrOfPictures":"nr_of_pictures"}, axis=1, inplace=True)
autos.rename({"postalCode":"postal_code"}, axis=1, inplace=True)
autos.rename({"lastSeen":"last_seen"}, axis=1, inplace=True)

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# I made the column headers more descriptive by making them snakecase.

# %%
autos.describe(include = 'all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-23 19:38:20  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_ps  model  \
# ...

# %%
print(autos["registration_year"].value_counts())
print(autos["price"].value_counts())
print(autos["odometer"].value_counts())
# Out:
# 2000    3354
# 2005    3015
# 1999    3000
# 2004    2737
# 2003    2727
# 2006    2708
# 2001    2703
# 2002    2533
# 1998    2453
# 2007    2304
# 2008    2231
# 2009    2098
# 1997    2028
# 2011    1634
# 2010    1597
# 2017    1453
# 1996    1444
# 2012    1323
# 2016    1316
# 1995    1313
# 2013     806
# 2014     666
# 1994     660
# 2018     492
# 1993     445
# 2015     399
# 1990     395
# 1992     391
# 1991     356
# 1989     181
#         ...
# 1950       3
# 1955       2
# 9000       2
# 1954       2
# 1800       2
# 1957       2
# 1941       2
# 1951       2
# 1934       2
# 4100       1
# 4800       1
# 1953       1
# 1111       1
# 1927       1
# 6200       1
# 4500       1
# 1943       1
# 5911       1
# 1939       1
# 1938       1
# 2800       1
# 8888       1
# 1000       1
# 1500       1
# 1948       1
# 1931       1
# 1929       1
# 1001       1
# 9996       1
# 1952       1
# Name: registration_year, Length: 97, dtype: int64
# $0          1421
# ...

# %% [markdown]
# The columns with mostly one value may be considered for deletion. e.g seller, offer type, etc
# Number of pictures column has to be checked as the data impliens there isn't a single picture on the database.
# Registration year needs a closer look as some years are too in the future and too in the past.
#
# Also, price and odometer columns are numeric data stored as text. These will need to be changed.

# %%
autos["price"] = autos["price"].str.replace("$","")
autos["price"] = autos["price"].str.replace(",","")
autos["price"] = autos["price"].astype(int)
autos["price"] = autos["price"].round(3)
autos["odometer"] = autos["odometer"].str.replace("km","")
autos["odometer"] = autos["odometer"].str.replace(",","")
autos["odometer"] = autos["odometer"].astype(int)
autos["odometer"] = autos["odometer"].round(5)
autos.rename({"odometer":"odometer_km"}, axis=1, inplace=True)

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type  price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot   5000  control          bus               2004
# 1  privat    Angebot   8500  control    limousine               1997
# 2  privat    Angebot   8990     test    limousine               2009
# 3  privat    Angebot   4350  control   kleinwagen               2007
# 4  privat    Angebot   1350     test        kombi               2003
#
#      gearbox  power_ps   model  odometer_km  registration_month fuel_type  \
# ...

# %%
autos.describe()
# Out:
#               price  registration_year      power_ps    odometer_km  \
# count  5.000000e+04       50000.000000  50000.000000   50000.000000
# mean   9.840044e+03        2005.073280    116.355920  125732.700000
# std    4.811044e+05         105.712813    209.216627   40042.211706
# min    0.000000e+00        1000.000000      0.000000    5000.000000
# 25%    1.100000e+03        1999.000000     70.000000  125000.000000
# 50%    2.950000e+03        2003.000000    105.000000  150000.000000
# 75%    7.200000e+03        2008.000000    150.000000  150000.000000
# max    1.000000e+08        9999.000000  17700.000000  150000.000000
#
#        registration_month  nr_of_pictures   postal_code
# count        50000.000000         50000.0  50000.000000
# mean             5.723360             0.0  50813.627300
# std              3.711984             0.0  25779.747957
# min              0.000000             0.0   1067.000000
# 25%              3.000000             0.0  30451.000000
# ...

# %%
autos["odometer_km"].unique().shape
# Out:
# (13,)

# %%
autos["odometer_km"].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos["odometer_km"].value_counts()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64

# %%
autos["odometer_km"].value_counts().head().sort_index(ascending=False)
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# Name: odometer_km, dtype: int64

# %%
autos["price"].sort_values(ascending=False).head()
# Out:
# 39705    99999999
# 42221    27322222
# 39377    12345678
# 47598    12345678
# 27371    12345678
# Name: price, dtype: int64

# %%
autos.loc[42221,:]
# Out:
# date_crawled          2016-03-08 20:39:05
# name                    Leasinguebernahme
# seller                             privat
# offer_type                        Angebot
# price                            27322222
# abtest                            control
# vehicle_type                    limousine
# registration_year                    2014
# gearbox                           manuell
# power_ps                              163
# model                                  c4
# odometer_km                         40000
# registration_month                      2
# fuel_type                          diesel
# brand                             citroen
# unrepaired_damage                     NaN
# ad_created            2016-03-08 00:00:00
# nr_of_pictures                          0
# postal_code                         76532
# last_seen             2016-03-08 20:39:05
# Name: 42221, dtype: object

# %%
autos["price"].value_counts().tail(100).sort_index(ascending = True)
# Out:
# 14        1
# 173       1
# 188       1
# 205       1
# 238       1
# 269       1
# 686       1
# 846       1
# 860       1
# 910       1
# 1039      1
# 1070      1
# 1295      1
# 1325      1
# 1485      1
# 1645      1
# 1659      1
# 1775      1
# 1933      1
# 1935      1
# 2095      1
# 2479      1
# 2589      1
# 2671      1
# 2895      1
# 3020      1
# 3055      1
# 3119      1
# 3279      1
# 3660      1
#          ..
# 21959     1
# 22790     1
# 23590     1
# 24550     1
# 25698     1
# 25699     1
# 27299     1
# 27650     1
# 28290     1
# 28850     1
# 29600     1
# 29699     1
# 30899     1
# 33980     1
# 41800     1
# 41850     1
# 46200     1
# 47499     1
# 48600     1
# 48888     1
# 56800     1
# 68300     1
# 68750     1
# 69900     1
# 69999     1
# 86500     1
# 115991    1
# 151990    1
# 175000    1
# 194000    1
# Name: price, Length: 100, dtype: int64

# %%
autos["price"].unique().shape
# Out:
# (2357,)

# %%
autos["price"].max()
# Out:
# 99999999

# %%
autos["price"].head()
# Out:
# 0    5000
# 1    8500
# 2    8990
# 3    4350
# 4    1350
# Name: price, dtype: int64

# %% [markdown]
# We will now remove outliers from the two columns

# %%
autos = autos[autos["price"].between(1000,5000000)]

# %%
autos = autos[autos["odometer_km"].between(1000,150000)]

# %%
autos.describe()
# Out:
#               price  registration_year      power_ps    odometer_km  \
# count  3.863200e+04       38632.000000  38632.000000   38632.000000
# mean   7.498207e+03        2005.678194    128.928531  122775.807621
# std    2.535787e+04          86.678597    215.903018   40800.492791
# min    1.000000e+03        1000.000000      0.000000    5000.000000
# 25%    2.200000e+03        2001.000000     80.000000  100000.000000
# 50%    4.350000e+03        2005.000000    116.000000  150000.000000
# 75%    8.950000e+03        2009.000000    160.000000  150000.000000
# max    3.890000e+06        9999.000000  17700.000000  150000.000000
#
#        registration_month  nr_of_pictures   postal_code
# count        38632.000000         38632.0  38632.000000
# mean             5.998835             0.0  51690.564765
# std              3.591214             0.0  25689.463891
# min              0.000000             0.0   1067.000000
# 25%              3.000000             0.0  31224.000000
# ...

# %%
autos["odometer_km"].value_counts()
# Out:
# 150000    23317
# 125000     4341
# 100000     1860
# 90000      1569
# 80000      1334
# 70000      1154
# 60000      1099
# 50000       987
# 40000       795
# 30000       748
# 20000       692
# 5000        508
# 10000       228
# Name: odometer_km, dtype: int64

# %%
len(autos["odometer_km"])
# Out:
# 38632

# %%
print(autos['date_crawled'].str[:10])
print("\n")
print(autos['ad_created'].str[:10])
print("\n")
print(autos['last_seen'].str[:10])
# Out:
# 0        2016-03-26
# 1        2016-04-04
# 2        2016-03-26
# 3        2016-03-12
# 4        2016-04-01
# 5        2016-03-21
# 7        2016-03-16
# 12       2016-03-31
# 13       2016-03-23
# 14       2016-03-23
# 15       2016-04-01
# 17       2016-03-29
# 19       2016-03-17
# 20       2016-03-05
# 21       2016-03-06
# 22       2016-03-28
# 23       2016-03-10
# 24       2016-04-03
# 28       2016-03-19
# 29       2016-04-02
# 31       2016-03-14
# 33       2016-03-15
# 34       2016-04-05
# 35       2016-03-29
# 36       2016-03-16
# 37       2016-03-23
# 38       2016-03-21
# 39       2016-03-11
# 40       2016-03-07
# 41       2016-03-10
#             ...
# 49962    2016-03-14
# 49963    2016-03-26
# 49964    2016-03-10
# 49965    2016-03-11
# 49966    2016-04-02
# 49967    2016-03-12
# 49968    2016-04-01
# 49969    2016-03-17
# 49970    2016-03-21
# 49972    2016-03-26
# 49973    2016-03-27
# 49975    2016-03-27
# 49976    2016-03-19
# 49977    2016-03-31
# ...

# %%
autos['date_crawled'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05    0.025549
# 2016-03-06    0.013875
# 2016-03-07    0.035126
# 2016-03-08    0.032615
# 2016-03-09    0.032460
# 2016-03-10    0.033314
# 2016-03-11    0.032797
# 2016-03-12    0.037378
# 2016-03-13    0.015997
# 2016-03-14    0.036628
# 2016-03-15    0.033625
# 2016-03-16    0.029069
# 2016-03-17    0.030493
# 2016-03-18    0.012839
# 2016-03-19    0.035126
# 2016-03-20    0.038155
# 2016-03-21    0.037301
# 2016-03-22    0.032538
# 2016-03-23    0.032201
# 2016-03-24    0.029017
# 2016-03-25    0.030519
# 2016-03-26    0.033107
# 2016-03-27    0.031399
# 2016-03-28    0.035359
# 2016-03-29    0.033987
# 2016-03-30    0.033055
# 2016-03-31    0.031399
# 2016-04-01    0.034609
# 2016-04-02    0.036291
# 2016-04-03    0.039139
# 2016-04-04    0.036912
# 2016-04-05    0.013357
# 2016-04-06    0.003262
# 2016-04-07    0.001501
# Name: date_crawled, dtype: float64

# %% [markdown]
# **The date crawled dates are between March and April. Date crawled seems to have a wide distribution with no particular date concentration**

# %%
autos['ad_created'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2015-06-11    0.000026
# 2015-08-10    0.000026
# 2015-09-09    0.000026
# 2015-11-10    0.000026
# 2015-12-30    0.000026
# 2016-01-03    0.000026
# 2016-01-07    0.000026
# 2016-01-10    0.000052
# 2016-01-13    0.000026
# 2016-01-14    0.000026
# 2016-01-16    0.000026
# 2016-01-22    0.000026
# 2016-01-27    0.000078
# 2016-01-29    0.000026
# 2016-02-01    0.000026
# 2016-02-02    0.000052
# 2016-02-05    0.000052
# 2016-02-07    0.000026
# 2016-02-09    0.000026
# 2016-02-11    0.000026
# 2016-02-12    0.000052
# 2016-02-14    0.000052
# 2016-02-16    0.000026
# 2016-02-17    0.000026
# 2016-02-18    0.000052
# 2016-02-19    0.000078
# 2016-02-20    0.000026
# 2016-02-21    0.000052
# 2016-02-22    0.000026
# 2016-02-23    0.000104
#                 ...
# 2016-03-09    0.032641
# 2016-03-10    0.032978
# 2016-03-11    0.033055
# 2016-03-12    0.037119
# 2016-03-13    0.017654
# 2016-03-14    0.034971
# 2016-03-15    0.033444
# 2016-03-16    0.029639
# 2016-03-17    0.030182
# ...

# %% [markdown]
# **There is a greater frequency of ads creation in 2016 than in 2015**

# %%
autos['last_seen'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05    0.001087
# 2016-03-06    0.003572
# 2016-03-07    0.004556
# 2016-03-08    0.006238
# 2016-03-09    0.008905
# 2016-03-10    0.009811
# 2016-03-11    0.011726
# 2016-03-12    0.022184
# 2016-03-13    0.008387
# 2016-03-14    0.011985
# 2016-03-15    0.014988
# 2016-03-16    0.015454
# 2016-03-17    0.026377
# 2016-03-18    0.007377
# 2016-03-19    0.014599
# 2016-03-20    0.019802
# 2016-03-21    0.019673
# 2016-03-22    0.020786
# 2016-03-23    0.017913
# 2016-03-24    0.018534
# 2016-03-25    0.017757
# 2016-03-26    0.016075
# 2016-03-27    0.014082
# 2016-03-28    0.019440
# 2016-03-29    0.020786
# 2016-03-30    0.023452
# 2016-03-31    0.022727
# 2016-04-01    0.023193
# 2016-04-02    0.024928
# 2016-04-03    0.024436
# 2016-04-04    0.023374
# 2016-04-05    0.131161
# 2016-04-06    0.234676
# 2016-04-07    0.139962
# Name: last_seen, dtype: float64

# %% [markdown]
# **There is a date concentration in April 2016. 49% of last seen were on three days in April**

# %%
autos["registration_year"].describe()
# Out:
# count    38632.000000
# mean      2005.678194
# std         86.678597
# min       1000.000000
# 25%       2001.000000
# 50%       2005.000000
# 75%       2009.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# There are outliers like year 1000 and year 9999 which are too old and too fururistic to be real. We remove these outliers.

# %%
autos["registration_year"].value_counts().sort_index()
# Out:
# 1000       1
# 1001       1
# 1927       1
# 1929       1
# 1931       1
# 1934       2
# 1937       4
# 1938       1
# 1939       1
# 1941       2
# 1943       1
# 1948       1
# 1950       1
# 1951       2
# 1952       1
# 1953       1
# 1954       2
# 1955       2
# 1956       4
# 1957       2
# 1958       3
# 1959       6
# 1960      17
# 1961       6
# 1962       4
# 1963       8
# 1964       9
# 1965      17
# 1966      21
# 1967      25
#         ...
# 1999    1725
# 2000    2001
# 2001    2065
# 2002    2135
# 2003    2477
# 2004    2608
# 2005    2785
# 2006    2652
# 2007    2259
# 2008    2204
# 2009    2077
# 2010    1584
# 2011    1617
# 2012    1306
# 2013     795
# 2014     649
# 2015     361
# 2016     651
# 2017    1008
# 2018     398
# 2019       1
# 2800       1
# 4100       1
# 4500       1
# 5000       2
# 5911       1
# 6200       1
# 8888       1
# 9000       1
# 9999       2
# Name: registration_year, Length: 91, dtype: int64

# %% [markdown]
# The earliest acceptable year is obviously 1927 as anything before that is medieval. We will remove any row with registration year after 2016, which is the last year any ad was seen.

# %%
autos = autos[autos["registration_year"].between(1900,2016)]

# %%
autos.describe()
# Out:
#               price  registration_year      power_ps    odometer_km  \
# count  3.721200e+04       37212.000000  37212.000000   37212.000000
# mean   7.605764e+03        2003.967618    129.496856  122540.175212
# std    2.581081e+04           7.021028    197.414831   40886.472839
# min    1.000000e+03        1927.000000      0.000000    5000.000000
# 25%    2.222000e+03        2001.000000     82.000000  100000.000000
# 50%    4.450000e+03        2005.000000    117.000000  150000.000000
# 75%    9.000000e+03        2008.000000    160.000000  150000.000000
# max    3.890000e+06        2016.000000  17700.000000  150000.000000
#
#        registration_month  nr_of_pictures   postal_code
# count        37212.000000         37212.0  37212.000000
# mean             6.042755             0.0  51828.871386
# std              3.574749             0.0  25680.166234
# min              0.000000             0.0   1067.000000
# 25%              3.000000             0.0  31275.000000
# ...

# %%
autos["registration_year"].value_counts(normalize=True)
# Out:
# 2005    0.074841
# 2006    0.071267
# 2004    0.070085
# 2003    0.066565
# 2007    0.060706
# 2008    0.059228
# 2002    0.057374
# 2009    0.055815
# 2001    0.055493
# 2000    0.053773
# 1999    0.046356
# 2011    0.043454
# 2010    0.042567
# 2012    0.035096
# 1998    0.034478
# 2013    0.021364
# 1997    0.021149
# 2016    0.017494
# 2014    0.017441
# 1996    0.014565
# 1995    0.011905
# 2015    0.009701
# 1994    0.007283
# 1992    0.005885
# 1993    0.005858
# 1991    0.005563
# 1990    0.005079
# 1989    0.003305
# 1988    0.002849
# 1985    0.002150
#           ...
# 1976    0.000564
# 1977    0.000537
# 1975    0.000484
# 1969    0.000484
# 1965    0.000457
# 1960    0.000457
# 1964    0.000242
# 1963    0.000215
# 1959    0.000161
# 1961    0.000161
# 1956    0.000107
# 1962    0.000107
# 1937    0.000107
# 1958    0.000081
# 1954    0.000054
# 1955    0.000054
# 1941    0.000054
# 1957    0.000054
# 1934    0.000054
# 1951    0.000054
# 1953    0.000027
# ...

# %% [markdown]
# Over 1000 entries (reg year after 2016) have been deleted. Most of the cars were registered in the early 2000s

# %%
autos["brand"].value_counts()
# Out:
# volkswagen        7845
# bmw               4665
# mercedes_benz     4152
# audi              3631
# opel              3314
# ford              2185
# renault           1387
# peugeot           1038
# fiat               784
# skoda              709
# seat               643
# smart              618
# toyota             544
# mazda              530
# citroen            517
# nissan             507
# mini               405
# hyundai            400
# sonstige_autos     391
# volvo              334
# kia                286
# porsche            278
# honda              273
# mitsubishi         256
# chevrolet          246
# alfa_romeo         232
# suzuki             213
# dacia              122
# chrysler           118
# jeep               103
# land_rover          98
# jaguar              69
# subaru              64
# daihatsu            63
# saab                51
# daewoo              34
# trabant             32
# rover               27
# lancia              25
# lada                23
# ...

# %%
autos["brand"].unique()
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'audi', 'renault', 'sonstige_autos', 'mazda', 'porsche', 'mini',
#        'mercedes_benz', 'seat', 'toyota', 'opel', 'dacia', 'jeep', 'saab',
#        'volvo', 'nissan', 'jaguar', 'skoda', 'subaru', 'fiat',
#        'mitsubishi', 'chevrolet', 'hyundai', 'honda', 'kia', 'citroen',
#        'suzuki', 'trabant', 'land_rover', 'alfa_romeo', 'rover',
#        'daihatsu', 'daewoo', 'lancia', 'lada'], dtype=object)

# %%
top_car_count = autos["brand"].value_counts().head(20).index

# %% [markdown]
# I have chosen to aggregate on the top 20 most popular brands. The working is below.

# %%
top_20_cars_price = {}
for car in top_car_count:
    selected_rows = autos[autos["brand"] == car]
    mean_price = selected_rows["price"].mean()
    top_20_cars_price[car] = mean_price

# %%
print(top_20_cars_price)
# Out:
# {'smart': 3780.4692556634304, 'renault': 3590.942321557318, 'citroen': 4614.970986460348, 'peugeot': 3955.169556840077, 'nissan': 6428.428007889546, 'sonstige_autos': 27654.273657289003, 'mercedes_benz': 9302.614402697494, 'fiat': 4008.174744897959, 'skoda': 6836.696755994359, 'volvo': 6151.583832335329, 'audi': 10322.269347287249, 'ford': 5786.703432494279, 'volkswagen': 6898.376545570427, 'bmw': 9381.89174705252, 'hyundai': 6181.8725, 'toyota': 5573.57169117647, 'mazda': 5309.526415094339, 'seat': 5638.640746500778, 'opel': 4219.954737477368, 'mini': 10715.237037037037}

# %%
top_20_cars_miles = {}
for car in top_car_count:
    selected_rows = autos[autos["brand"] == car]
    mean_mileage = selected_rows["odometer_km"].mean()
    top_20_cars_miles[car] = mean_mileage

# %%
print(top_20_cars_miles)
# Out:
# {'smart': 97775.08090614887, 'renault': 121423.93655371305, 'citroen': 114245.64796905222, 'peugeot': 122341.04046242774, 'nissan': 110335.3057199211, 'sonstige_autos': 89411.76470588235, 'mercedes_benz': 130062.6204238921, 'fiat': 107901.78571428571, 'skoda': 110063.46967559944, 'volvo': 137230.53892215568, 'audi': 127491.04929771413, 'ford': 119622.42562929062, 'volkswagen': 125771.82919056724, 'bmw': 132005.359056806, 'hyundai': 101862.5, 'toyota': 113740.80882352941, 'mazda': 119981.1320754717, 'seat': 116104.19906687403, 'opel': 123952.92697646348, 'mini': 88679.01234567902}

# %%
bmp_series = pd.Series(top_20_cars_price)
print(bmp_series)
# Out:
# audi              10322.269347
# bmw                9381.891747
# citroen            4614.970986
# fiat               4008.174745
# ford               5786.703432
# hyundai            6181.872500
# mazda              5309.526415
# mercedes_benz      9302.614403
# mini              10715.237037
# nissan             6428.428008
# opel               4219.954737
# peugeot            3955.169557
# renault            3590.942322
# seat               5638.640747
# skoda              6836.696756
# smart              3780.469256
# sonstige_autos    27654.273657
# toyota             5573.571691
# volkswagen         6898.376546
# volvo              6151.583832
# dtype: float64

# %%
top_mileage_series = pd.Series(top_20_cars_miles)
print(top_mileage_series)
# Out:
# audi              127491.049298
# bmw               132005.359057
# citroen           114245.647969
# fiat              107901.785714
# ford              119622.425629
# hyundai           101862.500000
# mazda             119981.132075
# mercedes_benz     130062.620424
# mini               88679.012346
# nissan            110335.305720
# opel              123952.926976
# peugeot           122341.040462
# renault           121423.936554
# seat              116104.199067
# skoda             110063.469676
# smart              97775.080906
# sonstige_autos     89411.764706
# toyota            113740.808824
# volkswagen        125771.829191
# volvo             137230.538922
# dtype: float64

# %%
top_20_cars = pd.DataFrame(top_mileage_series, columns=['mean_mileage'])
top_20_cars["mean_price"] = pd.DataFrame(bmp_series, columns=['mean_price'])

top_20_cars.sort_values("mean_price", ascending = False)
# Out:
#                  mean_mileage    mean_price
# sonstige_autos   89411.764706  27654.273657
# mini             88679.012346  10715.237037
# audi            127491.049298  10322.269347
# bmw             132005.359057   9381.891747
# mercedes_benz   130062.620424   9302.614403
# volkswagen      125771.829191   6898.376546
# skoda           110063.469676   6836.696756
# nissan          110335.305720   6428.428008
# hyundai         101862.500000   6181.872500
# volvo           137230.538922   6151.583832
# ford            119622.425629   5786.703432
# seat            116104.199067   5638.640747
# toyota          113740.808824   5573.571691
# mazda           119981.132075   5309.526415
# citroen         114245.647969   4614.970986
# opel            123952.926976   4219.954737
# fiat            107901.785714   4008.174745
# peugeot         122341.040462   3955.169557
# smart            97775.080906   3780.469256
# renault         121423.936554   3590.942322

# %% [markdown]
# There seems to be a slight inverse proportional relationship between mileage and price. Sonstige autos have the highest mean price and the lowest mean mileage, while it is vice versa for volvo.
